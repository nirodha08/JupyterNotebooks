# %%
#from __future__ import print_function
#from ipywidgets import interact, interactive, fixed, interact_manual
#import ipywidgets as widgets
import numpy as np
import pandas as pd
from scipy import optimize
#import matplotlib
#import matplotlib.pyplot as plt
#import matplotlib.ticker as ticker
import scipy

# %%
#%matplotlib inline
#import mpld3
#mpld3.enable_notebook()

# %%
#%matplotlib notebook
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt

# %% [markdown]
# ## Tungsten - Halogen Reference Spectrum

# %%
ref = pd.read_csv('tun_ref.TXT', header=None, skiprows=0)

wav = ref[0][:-1].values
val = ref[1][:-1].values

wav = np.ndarray.tolist(wav)
val = np.ndarray.tolist(val)

wav = map(float,wav)
val = map(float,val)

wav = list(wav)
val = list(val)

#wav = [x**-9 for x in wav]

#plt.plot(wav, val)

def energy(lam):    ## Energy in Joules
    h = 6.62607015*10**-34 # plancks constant
    c = 299792458 #speed of light
    
    return [(h*c)/(lam*10**-9) for lam in lam]

E_ref = energy(wav)
E_ev = [E_ref * 6.241509*10**18 for E_ref in E_ref]

plt.plot(E_ev,val)
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('Tungsten - Halogen Reference Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Sample 150 A - Room Temperature Reference

# %%
rm_150 = pd.read_csv('150_room_temp.TXT', header=None, skiprows=0)

w_150 = rm_150[0][:-1].values
v_150 = rm_150[1][:-1].values

w_150 = np.ndarray.tolist(w_150)
v_150 = np.ndarray.tolist(v_150)

w_150 = map(float,w_150)
v_150 = map(float,v_150)

w_150 = list(w_150)
v_150 = list(v_150)

plt.plot(E_ev[1:], v_150[1:])
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('Room Temperature 150A Sample Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Sample 150 A - Liquid Nitrogen

# %%
s1_ln = pd.read_csv('150_liquid_nitrogen.TXT', header=None, skiprows=0)

w1_ln = s1_ln[0][:-1].values
v1_ln = s1_ln[1][:-1].values

w1_ln = np.ndarray.tolist(w1_ln)
v1_ln = np.ndarray.tolist(v1_ln)

w1_ln = map(float,w1_ln)
v1_ln = map(float,v1_ln)

w1_ln = list(w1_ln)
v1_ln = list(v1_ln)

plt.plot(E_ev[1:], v1_ln[1:])
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('Liquid Nitrogen 150A Sample Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Sample 150 on same plot

# %%
plt.plot(E_ev[1:], v_150[1:])
plt.plot(E_ev[1:], v1_ln[1:])
plt.xlim(1,2.25)
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('150A Sample Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### 77K (Liquid Nitrogen) 150A Spectrum Features

# %%
plt.plot(E_ev[1:], v1_ln[1:])
plt.xlim(1.2,2)
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('77K 150A Sample Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Sample 200 A - Room Temperature Reference

# %%
s2_rm = pd.read_csv('200_room_temp.TXT', header=None, skiprows=0)

w2_rm = s2_rm[0][:-1].values
v2_rm = s2_rm[1][:-1].values

w2_rm = np.ndarray.tolist(w2_rm)
v2_rm = np.ndarray.tolist(v2_rm)

w2_rm = map(float,w2_rm)
v2_rm = map(float,v2_rm)

w2_rm = list(w2_rm)
v2_rm = list(v2_rm)

plt.plot(E_ev[1:], v2_rm[1:])
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('Room Temperature 200A Sample Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
s2_ln = pd.read_csv('200_liquid_nitrogen.TXT', header=None, skiprows=0)

w2_ln = s2_ln[0][:-1].values
v2_ln = s2_ln[1][:-1].values

w2_ln = np.ndarray.tolist(w2_ln)
v2_ln = np.ndarray.tolist(v2_ln)

w2_ln = map(float,w2_ln)
v2_ln = map(float,v2_ln)

w2_ln = list(w2_ln)
v2_ln = list(v2_ln)

plt.plot(E_ev[1:], v2_ln[1:])
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('Liquid Nitrogen 200A Sample Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.plot(E_ev[1:], v2_ln[1:])
plt.plot(E_ev[1:], v2_rm[1:])
#plt.xlim(E_ref[600],E_ref[4000])
plt.xlim(1,2.25)
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('200A Sample Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
Ga_rm = pd.read_csv('GaAs_room.TXT', header=None, skiprows=0)

Ga_w = Ga_rm[0][:-1].values
Ga_v = Ga_rm[1][:-1].values

Ga_w = np.ndarray.tolist(Ga_w)
Ga_v = np.ndarray.tolist(Ga_v)

Ga_w = map(float,Ga_w)
Ga_v = map(float,Ga_v)

Ga_w = list(Ga_w)
Ga_v = list(Ga_v)

plt.plot(E_ev[1:], Ga_v[1:])
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('GaAs Room Temperature Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
Ga_ln = pd.read_csv('GaAs_LN.TXT', header=None, skiprows=0)

Ga_w_l = Ga_ln[0][:-1].values
Ga_v_l = Ga_ln[1][:-1].values

Ga_w_l = np.ndarray.tolist(Ga_w_l)
Ga_v_l = np.ndarray.tolist(Ga_v_l)

Ga_w_l = map(float,Ga_w_l)
Ga_v_l = map(float,Ga_v_l)

Ga_w_l = list(Ga_w_l)
Ga_v_l = list(Ga_v_l)

plt.plot(E_ev[1:], Ga_v_l[1:])
plt.xlabel('Photon Energy (eV)')
plt.ylabel('Reflectivity (a.u)')
plt.title('GaAs Liquid Nitrogen Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="528.1818067337858">
